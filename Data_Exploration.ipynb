# %%
import pandas as pd
import sys
import sklearn
import numpy as np 
import matplotlib.pyplot as plt

# %%
def load_data(name):
    return pd.read_csv(csv_path)

ticker = "VOO_features.csv"
df = pd.read_csv(ticker) 
df = df[df.MACD_Signal_Line != 0]
df = df[df.Next_Close > 0]
df.head()
# Out:
#           Date       Close   Volume  Next_Close        RSI       20SMA  \
# 33  2018-03-05  250.199997  3024600  250.830002  50.575205  247.505999
# 34  2018-03-06  250.830002  1932000  250.720001  51.509479  247.907999
# 35  2018-03-07  250.720001  2730200  251.889999  51.327042  248.079999
# 36  2018-03-08  251.889999  3021600  256.250000  53.224689  248.378000
# 37  2018-03-09  256.250000  2450800  256.000000  59.553155  249.351000
#
#        BBLower     BBUpper       STD    ZScore      MACD  MACD_Signal_Line  \
# 33  238.991402  256.020596  4.257298  0.632795 -1.998865         -2.663950
# 34  239.564523  256.251476  4.171738  0.700428 -1.738956         -2.478951
# 35  239.653977  256.506022  4.213011  0.626631 -1.524281         -2.288017
# 36  239.856184  256.899816  4.260908  0.824237 -1.245385         -2.079491
# 37  241.977281  256.724719  3.686859  1.871240 -0.664877         -1.796568
#
#     Days_Change  GreenRed
# 33     0.630005         1
# 34    -0.110001         0
# ...

# %%
df.hist(bins=50, figsize=(20,15))
# save_fig("attribute_histogram_plots")
plt.show() # pandas internally uses matplotlib, and to display all the figures
           # the show() function must be called

# %%
from pandas.plotting import scatter_matrix
attributes = ["MACD_Signal_Line", "Volume", "ZScore","20SMA", "Days_Change"]
scatter_matrix(df[attributes], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x127a68710>,
# ...
#       dtype=object)
